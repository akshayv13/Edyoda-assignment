# %% [markdown]
# ### Program to count total number of odd and even numbers from a given set

# %%
a=[1, 2, 3, 4, 5, 6, 7, 8, 9]
even=0
odd=0
for i in a:
    if i%2==0:
        even+=1
    else:
        odd+=1
    
print("Even:",even,"\nodd:",odd)
# Out:
# Even: 4
# odd: 5
