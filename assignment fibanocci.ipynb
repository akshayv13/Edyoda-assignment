# %% [markdown]
# ### Program to print the fibanocci series between 0 to 50

# %%
s=1
b=1
print("The fibanocci series is:",end=" ")
while b<50:
        a=b
        print(b,end=" ")
        b=s
        s+=a
# Out:
# The fibanocci series is: 1 1 2 3 5 8 13 21 34
